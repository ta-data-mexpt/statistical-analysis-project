# %% [markdown]
# ## Load

# %%
import pandas as pd
import numpy as np

import matplotlib as plt
import seaborn as sns

import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('./data/train.csv', index_col = 'Id')

# %%
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %% [markdown]
# ## Explore & Clean

# %%
# I save original df in order to keep it intact from changes. 

df_original = df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
#  18  YearBuilt      1460 non-null   int64
#  19  YearRemodAdd   1460 non-null   int64
#  20  RoofStyle      1460 non-null   object
#  21  RoofMatl       1460 non-null   object
#  22  Exterior1st    1460 non-null   object
#  23  Exterior2nd    1460 non-null   object
#  24  MasVnrType     1452 non-null   object
#  25  MasVnrArea     1452 non-null   float64
#  26  ExterQual      1460 non-null   object
#  27  ExterCond      1460 non-null   object
#  28  Foundation     1460 non-null   object
#  29  BsmtQual       1423 non-null   object
#  30  BsmtCond       1423 non-null   object
#  31  BsmtExposure   1422 non-null   object
#  32  BsmtFinType1   1423 non-null   object
#  33  BsmtFinSF1     1460 non-null   int64
#  34  BsmtFinType2   1422 non-null   object
#  35  BsmtFinSF2     1460 non-null   int64
#  36  BsmtUnfSF      1460 non-null   int64
#  37  TotalBsmtSF    1460 non-null   int64
#  38  Heating        1460 non-null   object
#  39  HeatingQC      1460 non-null   object
#  40  CentralAir     1460 non-null   object
#  41  Electrical     1459 non-null   object
#  42  1stFlrSF       1460 non-null   int64
#  43  2ndFlrSF       1460 non-null   int64
#  44  LowQualFinSF   1460 non-null   int64
#  45  GrLivArea      1460 non-null   int64
#  46  BsmtFullBath   1460 non-null   int64
#  47  BsmtHalfBath   1460 non-null   int64
#  48  FullBath       1460 non-null   int64
#  49  HalfBath       1460 non-null   int64
#  50  BedroomAbvGr   1460 non-null   int64
#  51  KitchenAbvGr   1460 non-null   int64
#  52  KitchenQual    1460 non-null   object
#  53  TotRmsAbvGrd   1460 non-null   int64
#  54  Functional     1460 non-null   object
#  55  Fireplaces     1460 non-null   int64
#  56  FireplaceQu    770 non-null    object
#  57  GarageType     1379 non-null   object
#  58  GarageYrBlt    1379 non-null   float64
#  59  GarageFinish   1379 non-null   object
#  60  GarageCars     1460 non-null   int64
#  61  GarageArea     1460 non-null   int64
#  62  GarageQual     1379 non-null   object
#  63  GarageCond     1379 non-null   object
#  64  PavedDrive     1460 non-null   object
#  65  WoodDeckSF     1460 non-null   int64
#  66  OpenPorchSF    1460 non-null   int64
#  67  EnclosedPorch  1460 non-null   int64
#  68  3SsnPorch      1460 non-null   int64
#  69  ScreenPorch    1460 non-null   int64
#  70  PoolArea       1460 non-null   int64
#  71  PoolQC         7 non-null      object
#  72  Fence          281 non-null    object
#  73  MiscFeature    54 non-null     object
#  74  MiscVal        1460 non-null   int64
#  75  MoSold         1460 non-null   int64
#  76  YrSold         1460 non-null   int64
#  77  SaleType       1460 non-null   object
#  78  SaleCondition  1460 non-null   object
#  79  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(34), object(43)
# memory usage: 678.7+ KB

# %%
nulls = df.isnull().sum()
nulls = nulls[nulls > 0]

# %%
nulls
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
# LotFrontage
# lotFrontage nulls son un problema ya que no es posible que una propiedad no tenga frente a la calle
# para resolver esto considero que debe de haber una proporcion entre el LotFrontage (frente linear
# que da a la calle) y el LotArea ya que el LotArea = LotFrontage * LotDepth.
# Inicialmente voy a hacer una division para encontrar el fondo mediano.
# Tambien podria hacer una regresion lineal para buscar llenar estos NAs (lo intento si tengo tiempo)

df[:20]
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
# 6           50       RL         85.0    14115   Pave   NaN      IR1
# 7           20       RL         75.0    10084   Pave   NaN      Reg
# 8           60       RL          NaN    10382   Pave   NaN      IR1
# 9           50       RM         51.0     6120   Pave   NaN      Reg
# 10         190       RL         50.0     7420   Pave   NaN      Reg
# 11          20       RL         70.0    11200   Pave   NaN      Reg
# 12          60       RL         85.0    11924   Pave   NaN      IR1
# 13          20       RL          NaN    12968   Pave   NaN      IR2
# 14          20       RL         91.0    10652   Pave   NaN      IR1
# 15          20       RL          NaN    10920   Pave   NaN      IR1
# 16          45       RM         51.0     6120   Pave   NaN      Reg
# 17          20       RL          NaN    11241   Pave   NaN      IR1
# 18          90       RL         72.0    10791   Pave   NaN      Reg
# 19          20       RL         66.0    13695   Pave   NaN      Reg
# 20          20       RL         70.0     7560   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 6          Lvl    AllPub    Inside  ...        0    NaN  MnPrv        Shed
# 7          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 8          Lvl    AllPub    Corner  ...        0    NaN    NaN        Shed
# 9          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 10         Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 11         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 12         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 13         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 14         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 15         Lvl    AllPub    Corner  ...        0    NaN   GdWo         NaN
# 16         Lvl    AllPub    Corner  ...        0    NaN  GdPrv         NaN
# 17         Lvl    AllPub   CulDSac  ...        0    NaN    NaN        Shed
# 18         Lvl    AllPub    Inside  ...        0    NaN    NaN        Shed
# 19         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 20         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
# 6      700     10    2009        WD         Normal     143000
# 7        0      8    2007        WD         Normal     307000
# 8      350     11    2009        WD         Normal     200000
# 9        0      4    2008        WD        Abnorml     129900
# 10       0      1    2008        WD         Normal     118000
# 11       0      2    2008        WD         Normal     129500
# 12       0      7    2006       New        Partial     345000
# 13       0      9    2008        WD         Normal     144000
# 14       0      8    2007       New        Partial     279500
# 15       0      5    2008        WD         Normal     157000
# 16       0      7    2007        WD         Normal     132000
# 17     700      3    2010        WD         Normal     149000
# 18     500     10    2006        WD         Normal      90000
# 19       0      6    2008        WD         Normal     159000
# 20       0      5    2009       COD        Abnorml     139000
#
# [20 rows x 80 columns]

# %%
sns.scatterplot(x=df['LotFrontage'], y = df['LotArea']);

# %%
median_depth = df['LotArea'].median() / df['LotFrontage'].median()
median_depth
# Out:
# 137.3695652173913

# %%
df['LotFrontage'].fillna(df['LotArea'] / median_depth, inplace = True)
df['LotFrontage'].isnull().sum()
# Out:
# 0

# %%
# Alley
# Alley NAs are easy to fill since it is a category I only have to change the name so that it is
# recognized as a string.
df['Alley'].value_counts()
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %%
df['Alley'].fillna('NoAlley', inplace = True)
df['Alley'].value_counts()
# Out:
# NoAlley    1369
# Grvl         50
# Pave         41
# Name: Alley, dtype: int64

# %%
# MasVnrType
# I will assume NAs = None

df['MasVnrType'].value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
df['MasVnrType'].fillna('None', inplace = True)
df['MasVnrType'].value_counts()
# Out:
# None       872
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
# MasVnrArea
# this variable is a funtion of MasVnrType, since NAs in MasVnrArea coincide with None category of
# MasVnrType MasVnrArea should be = 0

df_original[['MasVnrType','MasVnrArea']][df_original['MasVnrArea'].isnull()]
# Out:
#      MasVnrType  MasVnrArea
# Id
# 235        None         NaN
# 530        None         NaN
# 651        None         NaN
# 937        None         NaN
# 974        None         NaN
# 978        None         NaN
# 1244       None         NaN
# 1279       None         NaN

# %%
df['MasVnrArea'].fillna(0, inplace = True)
df['MasVnrArea'].isnull().sum()
# Out:
# 0

# %%
# Basement variables (BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinType2)
# I will fill the NAs with 'No Basement' values
# I will deal first with the tw values that have 38 NAs and then with all of them together. 

df[['BsmtQual','BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']][df['BsmtFinType2'].isnull()]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2
# Id
# 18        NaN      NaN          NaN          NaN          NaN
# 40        NaN      NaN          NaN          NaN          NaN
# 91        NaN      NaN          NaN          NaN          NaN
# 103       NaN      NaN          NaN          NaN          NaN
# 157       NaN      NaN          NaN          NaN          NaN
# 183       NaN      NaN          NaN          NaN          NaN
# 260       NaN      NaN          NaN          NaN          NaN
# 333        Gd       TA           No          GLQ          NaN
# 343       NaN      NaN          NaN          NaN          NaN
# 363       NaN      NaN          NaN          NaN          NaN
# 372       NaN      NaN          NaN          NaN          NaN
# 393       NaN      NaN          NaN          NaN          NaN
# 521       NaN      NaN          NaN          NaN          NaN
# 533       NaN      NaN          NaN          NaN          NaN
# 534       NaN      NaN          NaN          NaN          NaN
# 554       NaN      NaN          NaN          NaN          NaN
# 647       NaN      NaN          NaN          NaN          NaN
# 706       NaN      NaN          NaN          NaN          NaN
# 737       NaN      NaN          NaN          NaN          NaN
# 750       NaN      NaN          NaN          NaN          NaN
# 779       NaN      NaN          NaN          NaN          NaN
# 869       NaN      NaN          NaN          NaN          NaN
# 895       NaN      NaN          NaN          NaN          NaN
# 898       NaN      NaN          NaN          NaN          NaN
# 985       NaN      NaN          NaN          NaN          NaN
# 1001      NaN      NaN          NaN          NaN          NaN
# 1012      NaN      NaN          NaN          NaN          NaN
# 1036      NaN      NaN          NaN          NaN          NaN
# 1046      NaN      NaN          NaN          NaN          NaN
# 1049      NaN      NaN          NaN          NaN          NaN
# 1050      NaN      NaN          NaN          NaN          NaN
# 1091      NaN      NaN          NaN          NaN          NaN
# 1180      NaN      NaN          NaN          NaN          NaN
# 1217      NaN      NaN          NaN          NaN          NaN
# 1219      NaN      NaN          NaN          NaN          NaN
# 1233      NaN      NaN          NaN          NaN          NaN
# 1322      NaN      NaN          NaN          NaN          NaN
# 1413      NaN      NaN          NaN          NaN          NaN

# %%
df['BsmtExposure'][df['BsmtQual'] == 'Gd'].value_counts()
df.at[949, 'BsmtExposure'] = 'No'
# Out:
# No    359
# Av    135
# Gd     69
# Mn     54
# Name: BsmtExposure, dtype: int64

# %%
df.at[949, 'BsmtExposure'] = 'No'
df['BsmtExposure'][df['BsmtQual'] == 'Gd'].value_counts()
# Out:
# No    360
# Av    135
# Gd     69
# Mn     54
# Name: BsmtExposure, dtype: int64

# %%
df['BsmtFinType2'][df['BsmtQual'] == 'Gd'].value_counts()
df.at[333, 'BsmtFinType2'] = 'Unf'

# %%
df['BsmtFinType2'][df['BsmtQual'] == 'Gd'].value_counts()
# Out:
# Unf    568
# LwQ     17
# Rec     10
# GLQ      9
# BLQ      9
# ALQ      5
# Name: BsmtFinType2, dtype: int64

# %%
df[['BsmtQual','BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']][df['BsmtFinType2'].isnull()]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2
# Id
# 18        NaN      NaN          NaN          NaN          NaN
# 40        NaN      NaN          NaN          NaN          NaN
# 91        NaN      NaN          NaN          NaN          NaN
# 103       NaN      NaN          NaN          NaN          NaN
# 157       NaN      NaN          NaN          NaN          NaN
# 183       NaN      NaN          NaN          NaN          NaN
# 260       NaN      NaN          NaN          NaN          NaN
# 343       NaN      NaN          NaN          NaN          NaN
# 363       NaN      NaN          NaN          NaN          NaN
# 372       NaN      NaN          NaN          NaN          NaN
# 393       NaN      NaN          NaN          NaN          NaN
# 521       NaN      NaN          NaN          NaN          NaN
# 533       NaN      NaN          NaN          NaN          NaN
# 534       NaN      NaN          NaN          NaN          NaN
# 554       NaN      NaN          NaN          NaN          NaN
# 647       NaN      NaN          NaN          NaN          NaN
# 706       NaN      NaN          NaN          NaN          NaN
# 737       NaN      NaN          NaN          NaN          NaN
# 750       NaN      NaN          NaN          NaN          NaN
# 779       NaN      NaN          NaN          NaN          NaN
# 869       NaN      NaN          NaN          NaN          NaN
# 895       NaN      NaN          NaN          NaN          NaN
# 898       NaN      NaN          NaN          NaN          NaN
# 985       NaN      NaN          NaN          NaN          NaN
# 1001      NaN      NaN          NaN          NaN          NaN
# 1012      NaN      NaN          NaN          NaN          NaN
# 1036      NaN      NaN          NaN          NaN          NaN
# 1046      NaN      NaN          NaN          NaN          NaN
# 1049      NaN      NaN          NaN          NaN          NaN
# 1050      NaN      NaN          NaN          NaN          NaN
# 1091      NaN      NaN          NaN          NaN          NaN
# 1180      NaN      NaN          NaN          NaN          NaN
# 1217      NaN      NaN          NaN          NaN          NaN
# 1219      NaN      NaN          NaN          NaN          NaN
# 1233      NaN      NaN          NaN          NaN          NaN
# 1322      NaN      NaN          NaN          NaN          NaN
# 1413      NaN      NaN          NaN          NaN          NaN

# %%
df['BsmtQual'].fillna('No Basement', inplace = True)
df['BsmtCond'].fillna('No Basement', inplace = True)
df['BsmtExposure'].fillna('No Basement', inplace = True)
df['BsmtFinType1'].fillna('No Basement', inplace = True)
df['BsmtFinType2'].fillna('No Basement', inplace = True)

# %%
df[['BsmtQual','BsmtCond','BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']].isnull().sum()
# Out:
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# dtype: int64

# %%
# There is only one NA for Electrical, I will set it to 'Standard Circuit'

df['Electrical'].fillna('SBrkr', inplace = True)
df['Electrical'].isnull().sum()
# Out:
# 0

# %%
# FireplaceQu
# I will place FireplaceQu to 'No Fireplace'

df['FireplaceQu'].value_counts()
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %%
df['FireplaceQu'].fillna('NoFireplace', inplace = True)
df['FireplaceQu'].value_counts()
# Out:
# NoFireplace    690
# Gd             380
# TA             313
# Fa              33
# Ex              24
# Po              20
# Name: FireplaceQu, dtype: int64

# %%
# Garage
# I will fill the garage NAs variablesnwith 'NoGarage'

df['GarageType'].fillna('NoGarage', inplace = True)
df['GarageYrBlt'].fillna('NoGarage', inplace = True)
df['GarageFinish'].fillna('NoGarage', inplace = True)
df['GarageQual'].fillna('NoGarage', inplace = True)
df['GarageCond'].fillna('NoGarage', inplace = True)

df[['GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond']].isnull().sum()
# Out:
# GarageType      0
# GarageYrBlt     0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# dtype: int64

# %%
# Pool
# I will set the pool NAs to 'NoPool'

df['PoolQC'].fillna('NoPool', inplace = True)
df['PoolQC'].isnull().sum()
# Out:
# 0

# %%
# Fence
# I will set the fence NAs to 'NoFence'

df['Fence'].fillna('NoFence', inplace = True)
df['Fence'].isnull().sum()
# Out:
# 0

# %%
# MiscFeature
# I will set the MiscFeature NAs to 'None'

df['MiscFeature'].fillna('MiscFeature', inplace = True)
df['MiscFeature'].isnull().sum()
# Out:
# 0

# %%
nulls = df.isnull().sum()
nulls = nulls[nulls > 0]
nulls
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## ANOVA

# %% [markdown]
# I am using an ANOVA test to check which variables are worth keeping in my model and which variables
# it is better to drop.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Alley          1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
#  17  YearBuilt      1460 non-null   int64
#  18  YearRemodAdd   1460 non-null   int64
#  19  RoofStyle      1460 non-null   object
#  20  RoofMatl       1460 non-null   object
#  21  Exterior1st    1460 non-null   object
#  22  Exterior2nd    1460 non-null   object
#  23  MasVnrType     1460 non-null   object
#  24  MasVnrArea     1460 non-null   float64
#  25  ExterQual      1460 non-null   object
#  26  ExterCond      1460 non-null   object
#  27  Foundation     1460 non-null   object
#  28  BsmtQual       1460 non-null   object
#  29  BsmtCond       1460 non-null   object
#  30  BsmtExposure   1460 non-null   object
#  31  BsmtFinType1   1460 non-null   object
#  32  BsmtFinSF1     1460 non-null   int64
#  33  BsmtFinType2   1460 non-null   object
#  34  BsmtFinSF2     1460 non-null   int64
#  35  BsmtUnfSF      1460 non-null   int64
#  36  TotalBsmtSF    1460 non-null   int64
#  37  Heating        1460 non-null   object
#  38  HeatingQC      1460 non-null   object
#  39  CentralAir     1460 non-null   object
#  40  Electrical     1460 non-null   object
#  41  1stFlrSF       1460 non-null   int64
#  42  2ndFlrSF       1460 non-null   int64
#  43  LowQualFinSF   1460 non-null   int64
#  44  GrLivArea      1460 non-null   int64
#  45  BsmtFullBath   1460 non-null   int64
#  46  BsmtHalfBath   1460 non-null   int64
#  47  FullBath       1460 non-null   int64
#  48  HalfBath       1460 non-null   int64
#  49  BedroomAbvGr   1460 non-null   int64
#  50  KitchenAbvGr   1460 non-null   int64
#  51  KitchenQual    1460 non-null   object
#  52  TotRmsAbvGrd   1460 non-null   int64
#  53  Functional     1460 non-null   object
#  54  Fireplaces     1460 non-null   int64
#  55  FireplaceQu    1460 non-null   object
#  56  GarageType     1460 non-null   object
#  57  GarageYrBlt    1460 non-null   object
#  58  GarageFinish   1460 non-null   object
#  59  GarageCars     1460 non-null   int64
#  60  GarageArea     1460 non-null   int64
#  61  GarageQual     1460 non-null   object
#  62  GarageCond     1460 non-null   object
#  63  PavedDrive     1460 non-null   object
#  64  WoodDeckSF     1460 non-null   int64
#  65  OpenPorchSF    1460 non-null   int64
#  66  EnclosedPorch  1460 non-null   int64
#  67  3SsnPorch      1460 non-null   int64
#  68  ScreenPorch    1460 non-null   int64
#  69  PoolArea       1460 non-null   int64
#  70  PoolQC         1460 non-null   object
#  71  Fence          1460 non-null   object
#  72  MiscFeature    1460 non-null   object
#  73  MiscVal        1460 non-null   int64
#  74  MoSold         1460 non-null   int64
#  75  YrSold         1460 non-null   int64
#  76  SaleType       1460 non-null   object
#  77  SaleCondition  1460 non-null   object
#  78  SalePrice      1460 non-null   int64
# dtypes: float64(2), int64(34), object(43)
# memory usage: 691.5+ KB

# %%
i = 'MSSubClass'
dic = {}

model = ols(f'SalePrice ~ C({i})', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
dic[i] = anova_table['PR(>F)'][0]

dic
# Out:
# {'MSSubClass': 8.66216626608785e-79}

# %%
cols = df.columns
dic = {}

for i in cols:
    try:
        model = ols(f'SalePrice ~ C({i})', data = df).fit()
        anova_table = sm.stats.anova_lm(model, typ=2)
        dic[i] = anova_table['PR(>F)'][0]
        
    except:
        print(i)
        
dic
# Out:
# 1stFlrSF
# 2ndFlrSF
# 3SsnPorch
# {'MSSubClass': 8.66216626608785e-79,
#  'MSZoning': 8.817633866285304e-35,
#  'LotFrontage': 6.610196968862629e-29,
#  'LotArea': 6.590819654754342e-50,
#  'Alley': 2.9963796805458385e-07,
#  'LotShape': 6.447523852008467e-25,
#  'LandContour': 2.7422167521366235e-08,
#  'LotConfig': 3.1631674736044365e-06,
#  'Neighborhood': 1.5586002827677873e-225,
#  'Condition1': 8.904549416140846e-08,
#  'Condition2': 0.043425658360948464,
#  'BldgType': 2.0567364604965262e-10,
#  'HouseStyle': 3.376776535121222e-25,
#  'OverallQual': 0.0,
#  'OverallCond': 7.962288819824339e-38,
#  'YearBuilt': 9.128103646602107e-107,
#  'YearRemodAdd': 2.3547477020636498e-76,
#  'RoofStyle': 3.6535230471027337e-17,
#  'RoofMatl': 7.231444779967662e-08,
#  'Exterior1st': 2.5860887286313106e-43,
#  'Exterior2nd': 4.842185670691115e-43,
#  'MasVnrType': 1.2797035312624795e-63,
#  'MasVnrArea': 1.5274395901136082e-52,
#  'ExterQual': 1.4395510967719157e-204,
#  'ExterCond': 5.106680608671862e-07,
#  'Foundation': 5.791895002234043e-91,
#  'BsmtQual': 8.15854808471181e-196,
#  'BsmtCond': 8.195793756122466e-16,
#  'BsmtExposure': 4.1030756854339634e-50,
#  'BsmtFinType1': 2.3863579356118723e-71,
#  'BsmtFinSF1': 1.4799695510414975e-26,
#  'BsmtFinType2': 1.0756883422084838e-08,
#  'BsmtUnfSF': 1.6361063234709793e-08,
#  'TotalBsmtSF': 1.268249225206014e-88,
#  'Heating': 0.0007534721064443111,
#  'HeatingQC': 2.6670620921029927e-67,
#  'CentralAir': 1.8095061559264767e-22,
#  'Electrical': 1.641207675776841e-18,
#  'LowQualFinSF': 0.25565603616958976,
#  'GrLivArea': 1.1649738558219938e-90,
#  'BsmtFullBath': 2.882435527293423e-17,
#  'BsmtHalfBath': 0.8013743052059724,
#  'FullBath': 3.802187932472066e-129,
#  'HalfBath': 1.6091449454036248e-31,
#  'BedroomAbvGr': 3.3043196450490515e-16,
#  'KitchenAbvGr': 2.011735142871395e-06,
#  'KitchenQual': 3.0322127528643642e-192,
#  'TotRmsAbvGrd': 1.191710336666924e-103,
#  'Functional': 0.0004841696801077666,
#  'Fireplaces': 4.421001030725402e-83,
#  'FireplaceQu': 2.971216972768991e-107,
#  'GarageType': 6.117025805426718e-87,
#  'GarageYrBlt': 1.240484589548232e-92,
#  'GarageFinish': 6.22874718150784e-115,
#  'GarageCars': 1.1211287650580619e-211,
#  'GarageArea': 1.0705140248740953e-158,
#  'GarageQual': 5.388762379335058e-25,
#  'GarageCond': 5.711745645679094e-25,
#  'PavedDrive': 1.803568890649982e-18,
#  'WoodDeckSF': 2.9149019687627637e-35,
#  'OpenPorchSF': 5.0577044186062795e-49,
#  'EnclosedPorch': 0.11421764338628304,
#  'ScreenPorch': 0.03675859519308868,
#  'PoolArea': 2.341047098544491e-09,
#  'PoolQC': 7.700989415722156e-07,
#  'Fence': 9.379976594788224e-11,
#  'MiscFeature': 0.03500367187544121,
#  'MiscVal': 0.47363977594201023,
#  'MoSold': 0.48335232989243127,
#  'YrSold': 0.6300887663574033,
#  'SaleType': 5.0397668894426123e-42,
#  'SaleCondition': 7.988268404983797e-44,
#  'SalePrice': 0.0}

# %%
model = ols('SalePrice ~ C(MSSubClass)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                      sum_sq      df          F        PR(>F)
# C(MSSubClass)  2.268056e+12    14.0  33.732076  8.662166e-79
# Residual       6.939856e+12  1445.0        NaN           NaN

# %%
model = ols('SalePrice ~ C(MSSubClass)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table

# %%
model = ols('SalePrice ~ C(MSZoning)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                    sum_sq      df          F        PR(>F)
# C(MSZoning)  9.904000e+11     4.0  43.840282  8.817634e-35
# Residual     8.217511e+12  1455.0        NaN           NaN

# %%
model = ols('SalePrice ~ C(LotFrontage)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                       sum_sq      df         F        PR(>F)
# C(LotFrontage)  3.980241e+12   344.0  2.467844  6.610197e-29
# Residual        5.227670e+12  1115.0       NaN           NaN

# %%
model = ols('SalePrice ~ C(LotArea)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                   sum_sq      df         F        PR(>F)
# C(LotArea)  8.463582e+12  1072.0  4.104925  6.590820e-50
# Residual    7.443294e+11   387.0       NaN           NaN

# %%
model = ols('SalePrice ~ C(Street)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                  sum_sq      df        F    PR(>F)
# C(Street)  1.550534e+10     1.0  2.45929  0.117049
# Residual   9.192406e+12  1458.0      NaN       NaN

# %%
df.drop('Street', axis = 1, inplace = True)

# %%
model = ols('SalePrice ~ C(Alley)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq      df          F        PR(>F)
# C(Alley)  1.879109e+11     2.0  15.176614  2.996380e-07
# Residual  9.020000e+12  1457.0        NaN           NaN

# %%
model = ols('SalePrice ~ C(LotShape)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                    sum_sq      df          F        PR(>F)
# C(LotShape)  7.032607e+11     3.0  40.132852  6.447524e-25
# Residual     8.504651e+12  1456.0        NaN           NaN

# %%
model = ols('SalePrice ~ C(LandContour)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                       sum_sq      df          F        PR(>F)
# C(LandContour)  2.375097e+11     3.0  12.850188  2.742217e-08
# Residual        8.970402e+12  1456.0        NaN           NaN

# %%
model = ols('SalePrice ~ C(Utilities)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                     sum_sq      df         F    PR(>F)
# C(Utilities)  1.886693e+09     1.0  0.298804  0.584717
# Residual      9.206025e+12  1458.0       NaN       NaN

# %%
df.drop('Utilities', axis = 1, inplace = True)

# %%
model = ols('SalePrice ~ C(LotConfig)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                     sum_sq      df         F    PR(>F)
# C(LotConfig)  1.935444e+11     4.0  7.809954  0.000003
# Residual      9.014367e+12  1455.0       NaN       NaN

# %%
model = ols('SalePrice ~ C(LandSlope)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                     sum_sq      df         F    PR(>F)
# C(LandSlope)  2.469217e+10     2.0  1.958817  0.141396
# Residual      9.183219e+12  1457.0       NaN       NaN

# %%
df.drop('LandSlope', axis = 1, inplace = True)

# %%
model = ols('SalePrice ~ C(Neighborhood)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                        sum_sq      df          F         PR(>F)
# C(Neighborhood)  5.023606e+12    24.0  71.784865  1.558600e-225
# Residual         4.184305e+12  1435.0        NaN            NaN

# %%
model = ols('SalePrice ~ C(Condition1)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                      sum_sq      df         F        PR(>F)
# C(Condition1)  3.004600e+11     8.0  6.118017  8.904549e-08
# Residual       8.907451e+12  1451.0       NaN           NaN

# %%
model = ols('SalePrice ~ C(Condition2)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                      sum_sq      df         F    PR(>F)
# C(Condition2)  9.115059e+10     7.0  2.073899  0.043426
# Residual       9.116761e+12  1452.0       NaN       NaN

# %%
model = ols('SalePrice ~ C(BldgType)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                    sum_sq      df          F        PR(>F)
# C(BldgType)  3.179863e+11     4.0  13.011077  2.056736e-10
# Residual     8.889925e+12  1455.0        NaN           NaN

# %%
model = ols('SalePrice ~ C(HouseStyle)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                      sum_sq      df          F        PR(>F)
# C(HouseStyle)  7.947590e+11     7.0  19.595001  3.376777e-25
# Residual       8.413152e+12  1452.0        NaN           NaN

# %%
model = ols('SalePrice ~ C(OverallQual)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                       sum_sq      df          F  PR(>F)
# C(OverallQual)  6.299881e+12     9.0  349.02684     0.0
# Residual        2.908031e+12  1450.0        NaN     NaN

# %%
model = ols('SalePrice ~ C(OverallCond)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                       sum_sq      df          F        PR(>F)
# C(OverallCond)  1.154581e+12     8.0  26.003173  7.962289e-38
# Residual        8.053330e+12  1451.0        NaN           NaN

# %%
model = ols('SalePrice ~ C(YearBuilt)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                     sum_sq      df         F         PR(>F)
# C(YearBuilt)  4.047789e+12   111.0  9.526311  9.128104e-107
# Residual      5.160123e+12  1348.0       NaN            NaN

# %%
model = ols('SalePrice ~ C(YearRemodAdd)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                        sum_sq      df          F        PR(>F)
# C(YearRemodAdd)  2.854751e+12    60.0  10.477193  2.354748e-76
# Residual         6.353160e+12  1399.0        NaN           NaN

# %%
model = ols('SalePrice ~ C(RoofStyle)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                     sum_sq      df          F        PR(>F)
# C(RoofStyle)  5.312655e+11     5.0  17.805497  3.653523e-17
# Residual      8.676646e+12  1454.0        NaN           NaN

# %%
model = ols('SalePrice ~ C(RoofMatl)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                    sum_sq      df         F        PR(>F)
# C(RoofMatl)  2.892493e+11     7.0  6.727305  7.231445e-08
# Residual     8.918662e+12  1452.0       NaN           NaN

# %%
model = ols('SalePrice ~ C(Exterior1st)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                       sum_sq      df          F        PR(>F)
# C(Exterior1st)  1.406721e+12    14.0  18.611743  2.586089e-43
# Residual        7.801190e+12  1445.0        NaN           NaN

# %%
model = ols('SalePrice ~ C(Exterior2nd)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                       sum_sq      df         F        PR(>F)
# C(Exterior2nd)  1.416452e+12    15.0  17.50084  4.842186e-43
# Residual        7.791460e+12  1444.0       NaN           NaN

# %%
model = ols('SalePrice ~ C(MasVnrType)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                      sum_sq      df           F        PR(>F)
# C(MasVnrType)  1.687597e+12     3.0  108.911305  1.279704e-63
# Residual       7.520314e+12  1456.0         NaN           NaN

# %%
model = ols('SalePrice ~ C(MasVnrArea)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                      sum_sq      df         F        PR(>F)
# C(MasVnrArea)  4.574026e+12   326.0  3.430565  1.527440e-52
# Residual       4.633885e+12  1133.0       NaN           NaN

# %%
model = ols('SalePrice ~ C(ExterQual)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                     sum_sq      df           F         PR(>F)
# C(ExterQual)  4.395744e+12     3.0  443.334831  1.439551e-204
# Residual      4.812167e+12  1456.0         NaN            NaN

# %%
model = ols('SalePrice ~ C(ExterCond)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                     sum_sq      df         F        PR(>F)
# C(ExterCond)  2.174690e+11     4.0  8.798714  5.106681e-07
# Residual      8.990442e+12  1455.0       NaN           NaN

# %%
model = ols('SalePrice ~ C(Foundation)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                      sum_sq      df           F        PR(>F)
# C(Foundation)  2.360618e+12     5.0  100.253851  5.791895e-91
# Residual       6.847294e+12  1454.0         NaN           NaN

# %%
model = ols('SalePrice ~ C(BsmtQual)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                    sum_sq      df           F         PR(>F)
# C(BsmtQual)  4.281621e+12     4.0  316.148635  8.158548e-196
# Residual     4.926290e+12  1455.0         NaN            NaN

# %%
model = ols('SalePrice ~ C(BsmtCond)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                    sum_sq      df          F        PR(>F)
# C(BsmtCond)  4.732480e+11     4.0  19.708139  8.195794e-16
# Residual     8.734663e+12  1455.0        NaN           NaN

# %%
model = ols('SalePrice ~ C(BsmtExposure)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                        sum_sq      df          F        PR(>F)
# C(BsmtExposure)  1.383210e+12     4.0  64.301816  4.103076e-50
# Residual         7.824702e+12  1455.0        NaN           NaN

# %%
model = ols('SalePrice ~ C(BsmtFinType1)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                        sum_sq      df        F        PR(>F)
# C(BsmtFinType1)  1.941124e+12     6.0  64.6882  2.386358e-71
# Residual         7.266788e+12  1453.0      NaN           NaN

# %%
model = ols('SalePrice ~ C(BsmtFinSF1)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                      sum_sq     df         F        PR(>F)
# C(BsmtFinSF1)  5.797519e+12  636.0  2.199787  1.479970e-26
# Residual       3.410392e+12  823.0       NaN           NaN

# %%
model = ols('SalePrice ~ C(BsmtFinType2)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                        sum_sq      df         F        PR(>F)
# C(BsmtFinType2)  3.000613e+11     6.0  8.157393  1.075688e-08
# Residual         8.907850e+12  1453.0       NaN           NaN

# %%
model = ols('SalePrice ~ C(BsmtFinSF2)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                      sum_sq      df         F    PR(>F)
# C(BsmtFinSF2)  5.091909e+11   143.0  0.538698  0.999997
# Residual       8.698720e+12  1316.0       NaN       NaN

# %%
df.drop('BsmtFinSF2', axis = 1, inplace = True)

# %%
model = ols('SalePrice ~ C(TotalBsmtSF)', data = df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                       sum_sq     df         F        PR(>F)
# C(TotalBsmtSF)  7.545507e+12  720.0  4.658688  1.268249e-88
# Residual        1.662405e+12  739.0       NaN           NaN

# %%
df_dummy = pd.get_dummies(data = df )

# %%
df_dummy.head()
# Out:
#     MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1           60         65.0     8450            7            5       2003
# 2           20         80.0     9600            6            8       1976
# 3           60         68.0    11250            7            5       2001
# 4           70         60.0     9550            7            5       1915
# 5           60         84.0    14260            8            5       2000
#
#     YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtUnfSF  ...  SaleType_ConLw  \
# Id                                                   ...
# 1           2003       196.0         706        150  ...               0
# 2           1976         0.0         978        284  ...               0
# 3           2002       162.0         486        434  ...               0
# 4           1970         0.0         216        540  ...               0
# 5           2000       350.0         655        490  ...               0
#
#     SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# Id
# 1              0             0            1                      0
# 2              0             0            1                      0
# 3              0             0            1                      0
# 4              0             0            1                      1
# 5              0             0            1                      0
#
#     SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# Id
# 1                       0                     0                     0
# 2                       0                     0                     0
# 3                       0                     0                     0
# 4                       0                     0                     0
# 5                       0                     0                     0
#
#     SaleCondition_Normal  SaleCondition_Partial
# Id
# 1                      1                      0
# 2                      1                      0
# 3                      1                      0
# 4                      0                      0
# 5                      1                      0
#
# [5 rows x 392 columns]

# %%
x = df_dummy.drop('SalePrice', axis = 1)
y = df_dummy['SalePrice']

linreg = LinearRegression()
linreg.fit(x, y)

coefficient = linreg.coef_
df_score = linreg.score(x,y)
y_intercept = linreg.intercept_

print('Coefficient:', coefficient)
print('y intercept:', y_intercept)
print('R squared:', df_score)
# Out:
# Coefficient: [-5.81511342e+01 -4.46484294e+01  6.09387855e-01  6.23365742e+03
#   5.67871311e+03  3.05532399e+02  1.08657467e+02  2.14538103e+01
#   9.73586353e+00 -8.07085902e+00  2.88136679e+01 -9.94419529e+11
#  -9.94419529e+11 -9.94419529e+11  9.94419529e+11  1.89624634e+03
#  -8.45789706e+02  4.75138242e+03  1.48085191e+03 -3.55306053e+03
#  -1.08122597e+04  2.09314786e+03  5.91256979e+03  5.08201952e+03
#   1.94915288e+01  1.71103761e+01  2.63678961e-01  9.70023972e+00
#   4.00812082e+01  3.70637203e+01  5.42311847e+02 -6.85783494e-01
#  -4.43980577e+02 -9.57944366e+02  1.97525359e+09  1.97527989e+09
#   1.97527104e+09  1.97527732e+09  1.97527235e+09  5.62387665e+08
#   5.62387734e+08  5.62387576e+08 -4.68075465e+08 -4.68070827e+08
#  -4.68069485e+08 -4.68073113e+08 -9.07669989e+07 -9.07585379e+07
#  -9.07730852e+07 -9.07619864e+07  4.28108237e+08  4.28116525e+08
#   4.28097288e+08  4.28089118e+08  4.28105898e+08  9.71199452e+07
#   9.71269908e+07  9.71250037e+07  9.71161308e+07  9.71080420e+07
#   9.71117121e+07  9.71351745e+07  9.71018533e+07  9.71105573e+07
#   9.71089034e+07  9.71208690e+07  9.71035831e+07  9.71062566e+07
#   9.71392978e+07  9.71080637e+07  9.71468847e+07  9.71387132e+07
#   9.71080986e+07  9.71105316e+07  9.71130867e+07  9.71197242e+07
#   9.71208599e+07  9.71595016e+07  9.71079451e+07  9.71240228e+07
#   1.87119206e+08  1.87128933e+08  1.87134425e+08  1.87133907e+08
#   1.87130993e+08  1.87103971e+08  1.87131735e+08  1.87118024e+08
#   1.87127382e+08 -1.24716628e+08 -1.24706745e+08 -1.24715053e+08
#  -1.24654712e+08 -1.24925765e+08 -1.24774622e+08 -1.24730437e+08
#  -1.24701904e+08  2.24221608e+09  2.24221409e+09  2.24220651e+09
#   2.24219541e+09  2.24220105e+09 -6.50174086e+07 -6.50030575e+07
#  -6.50111105e+07 -6.50348034e+07 -6.50223895e+07 -6.50218486e+07
#  -6.50177524e+07 -6.50118175e+07 -2.11974469e+08 -2.11970492e+08
#  -2.11970744e+08 -2.11969282e+08 -2.11966314e+08 -2.11937769e+08
#   5.85396362e+07  5.91408898e+07  5.91783978e+07  5.91599695e+07
#   5.91153831e+07  5.91352356e+07  5.91418452e+07  5.91991884e+07
#   1.07923496e+08  1.07896447e+08  1.07925878e+08  1.07934024e+08
#   1.54610682e+08  1.07920814e+08  1.07915580e+08  1.07900838e+08
#   1.07919885e+08  1.07915035e+08  1.07918679e+08  1.07911806e+08
#   1.07914244e+08  1.07916266e+08  1.07917080e+08  1.48310847e+08
#   1.48327480e+08  1.48305931e+08  1.48310246e+08  1.01615819e+08
#   1.48314504e+08  1.48314926e+08  1.48322934e+08  1.48313998e+08
#   1.48285428e+08  1.48313385e+08  1.48301786e+08  1.48327055e+08
#   1.48317412e+08  1.48315514e+08  1.48313374e+08  7.10523395e+08
#   7.10526456e+08  7.10529681e+08  7.10529004e+08  2.89017369e+08
#   2.89005003e+08  2.88999322e+08  2.88998286e+08  9.63566978e+07
#   9.63527041e+07  9.63479337e+07  9.63596144e+07  9.63499730e+07
#   5.42489486e+08  5.42494603e+08  5.42495215e+08  5.42485769e+08
#   5.42504485e+08  5.42477809e+08 -1.05396292e+09 -1.05397340e+09
#  -1.05398014e+09  1.17069394e+08 -1.05397834e+09 -1.71301960e+08
#  -1.71299928e+08  2.46675878e+07 -1.71274023e+08 -1.71297194e+08
#   7.57956931e+08  7.57972718e+08  7.57954147e+08  7.57951186e+08
#  -1.15843081e+08  4.19283189e+08  4.19287016e+08  4.19287234e+08
#   4.19280154e+08 -7.82465058e+07  4.19282727e+08  4.19284656e+08
#  -8.58225216e+07 -8.58293720e+07 -8.58223827e+07 -8.58288826e+07
#  -8.14952424e+07 -8.58302129e+07 -8.58269455e+07 -1.11314663e+08
#  -1.11309000e+08 -1.11304226e+08 -1.11310129e+08 -1.11329411e+08
#  -1.11306327e+08 -2.89471970e+08 -2.89470879e+08 -2.89476210e+08
#  -2.89475360e+08 -2.89476210e+08  7.10905799e+08  7.10905915e+08
#  -2.66268392e+07 -2.66277647e+07 -2.66284107e+07 -2.66206208e+07
#  -2.66300264e+07 -5.62554182e+07 -5.62728660e+07 -5.62756147e+07
#  -5.62739832e+07 -4.70049073e+07 -4.70112446e+07 -4.69952555e+07
#  -4.69937394e+07 -4.70067233e+07 -4.70303863e+07 -4.69846012e+07
#   1.06234148e+08  1.06228685e+08  1.06232379e+08  1.06238375e+08
#   1.06240477e+08  1.06232499e+08  5.40124039e+08  5.40151919e+08
#   5.40154815e+08  5.40152599e+08  5.40157353e+08  5.40153892e+08
#   4.46321214e+08 -7.42358524e+06 -7.39178056e+06 -7.36889127e+06
#  -7.39406052e+06 -7.39884607e+06 -7.39589041e+06 -7.39061435e+06
#  -7.48711674e+06 -7.38173821e+06 -7.37103913e+06 -7.37150110e+06
#  -7.36972761e+06 -7.39087196e+06 -7.37997582e+06 -7.38610621e+06
#  -7.36449402e+06 -7.38261464e+06 -7.37918458e+06 -7.37527505e+06
#  -7.38515713e+06 -7.36350394e+06 -7.38629051e+06 -7.35483976e+06
#  -7.38172215e+06 -7.37080224e+06 -7.38453978e+06 -7.38515932e+06
#  -7.37281675e+06 -7.37810519e+06 -7.38494128e+06 -7.38352467e+06
#  -7.38186960e+06 -7.39612712e+06 -7.38409543e+06 -7.37904365e+06
#  -7.38325312e+06 -7.38312831e+06 -7.39136052e+06 -7.40660091e+06
#  -7.39527183e+06 -7.38057068e+06 -7.39175822e+06 -7.38310929e+06
#  -7.39223361e+06 -7.38837767e+06 -7.38481645e+06 -7.38651414e+06
#  -7.39235236e+06 -7.37887449e+06 -7.39768859e+06 -7.39035428e+06
#  -7.39658597e+06 -7.38446445e+06 -7.38591361e+06 -7.39089539e+06
#  -7.39514464e+06 -7.39524453e+06 -7.39044525e+06 -7.38496016e+06
#  -7.39921992e+06 -7.37951227e+06 -7.39378698e+06 -7.39030450e+06
#  -7.39557501e+06 -7.38796105e+06 -7.38082871e+06 -7.38500199e+06
#  -7.39776083e+06 -7.38891872e+06 -7.38133464e+06 -7.40497089e+06
#  -7.39785499e+06 -7.39101123e+06 -7.38145606e+06 -7.39255321e+06
#  -7.37888066e+06 -7.39678393e+06 -7.38896816e+06 -7.39492066e+06
#  -7.39526341e+06 -7.38487953e+06 -7.37816444e+06 -7.39075492e+06
#  -7.38381523e+06 -7.38834400e+06 -7.38584160e+06 -7.38487988e+06
#  -7.38306253e+06 -7.38442181e+06 -7.38786517e+06 -7.38334271e+06
#  -7.38674568e+06 -7.38318172e+06 -7.39520703e+06 -7.37198473e+06
#  -7.36919570e+06 -7.37859967e+06  1.77808537e+08  9.51131521e+08
#   2.37093094e+08  9.51128074e+08  9.51130100e+08 -2.43438606e+08
#  -2.43569761e+08 -2.43561974e+08  1.87898141e+08 -2.43591984e+08
#  -2.43561050e+08  5.09421364e+07  5.10644954e+07  5.10613648e+07
#   2.42287121e+08  5.10705103e+07  5.10642731e+07 -3.81371190e+07
#  -3.81443069e+07 -3.81392964e+07 -1.60973947e+07 -1.62993268e+07
#  -1.62487265e+07 -1.59631050e+07  7.71135325e+07  7.71219137e+07
#   7.71234879e+07  7.71210241e+07  7.71219980e+07 -8.97347989e+07
#  -8.97426316e+07 -8.97314892e+07 -8.97396810e+07 -8.97209071e+07
#  -1.12058877e+08 -1.12045303e+08 -1.12038508e+08 -1.12050350e+08
#  -1.12053387e+08 -1.12054910e+08 -1.12023531e+08 -1.12057220e+08
#  -1.12059280e+08  9.21271727e+07  9.21366318e+07  9.21209589e+07
#   9.21232465e+07  9.21334674e+07  9.21106936e+07]
# y intercept: -7841709917.30411
# R squared: 0.9379621556715851

# %%
cols = df_dummy.corr()['SalePrice']
cols = cols[abs(cols) < 0.4].index

# %%
len(cols)
# Out:
# 365

# %%
df_dummy_drop = df_dummy.drop('FireplaceQu_NoFireplace', axis = 1)
df_dummy_drop = df_dummy.drop(cols, axis = 1)

# %%
x = df_dummy_drop.drop(['SalePrice','FireplaceQu_NoFireplace'], axis = 1)
y = df_dummy_drop['SalePrice']

linreg = LinearRegression()
linreg.fit(x, y)

coefficient = linreg.coef_
df_score = linreg.score(x,y)
y_intercept = linreg.intercept_

print('Coefficient:', coefficient)
print('y intercept:', y_intercept)
print('R squared:', df_score)
# Out:
# Coefficient: [ 1.11084719e+04  1.39971550e+02  1.72534979e+02  1.71268840e+01
#   1.38175635e+01  4.48741479e+00  4.51528047e+01 -1.60284013e+03
#  -1.54967112e+02  1.00922694e+04  1.08506214e+04  8.18015508e+00
#   1.08061817e+04  2.91565703e+04  1.27210779e+04  7.77779931e+03
#  -2.87529102e+03  3.05481154e+04  3.06407429e+02  1.25895203e+04
#   3.55374091e+03  2.59541940e+04 -5.80782654e+03  2.20053982e+03
#  -4.24772127e+03]
# y intercept: -636059.2560544742
# R squared: 0.8182652468086072

# %%
df_dummy_drop.columns
# Out:
# Index(['OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'TotalBsmtSF',
#        '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageCars', 'GarageArea', 'SalePrice', 'Neighborhood_NridgHt',
#        'ExterQual_Ex', 'ExterQual_Gd', 'ExterQual_TA', 'Foundation_PConc',
#        'BsmtQual_Ex', 'BsmtQual_TA', 'BsmtFinType1_GLQ', 'HeatingQC_Ex',
#        'KitchenQual_Ex', 'KitchenQual_TA', 'FireplaceQu_NoFireplace',
#        'GarageFinish_Fin', 'GarageFinish_Unf'],
#       dtype='object')

# %%
test = pd.read_csv('./test.csv', index_col = 'Id')

# %%
test = test[['OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'TotalBsmtSF',
       '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'Fireplaces',
       'GarageCars', 'GarageArea', 'SalePrice', 'Neighborhood_NridgHt',
       'ExterQual_Ex', 'ExterQual_Gd', 'ExterQual_TA', 'Foundation_PConc',
       'BsmtQual_Ex', 'BsmtQual_TA', 'BsmtFinType1_GLQ', 'HeatingQC_Ex',
       'KitchenQual_Ex', 'KitchenQual_TA', 'FireplaceQu_NoFireplace',
       'GarageFinish_Fin', 'GarageFinish_Unf']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-243-7bad0ed8e83f> in <module>
# ----> 1 test = test[['OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'TotalBsmtSF',
#       2        '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'Fireplaces',
#       3        'GarageCars', 'GarageArea', 'SalePrice', 'Neighborhood_NridgHt',
#       4        'ExterQual_Ex', 'ExterQual_Gd', 'ExterQual_TA', 'Foundation_PConc',
#       5        'BsmtQual_Ex', 'BsmtQual_TA', 'BsmtFinType1_GLQ', 'HeatingQC_Ex',
#
# c:\users\bravo\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# c:\users\bravo\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1263             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1264
# -> 1265         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1266         return keyarr, indexer
#    1267
#
# c:\users\bravo\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1313             if raise_missing:
#    1314                 not_found = list(set(key) - set(ax))
# -> 1315                 raise KeyError(f"{not_found} not in index")
#    1316
#    1317             not_found = key[missing_mask]
#
# KeyError: "['KitchenQual_Ex', 'FireplaceQu_NoFireplace', 'Foundation_PConc', 'ExterQual_TA', 'BsmtQual_TA', 'KitchenQual_TA', 'GarageFinish_Unf', 'GarageFinish_Fin', 'SalePrice', 'BsmtFinType1_GLQ', 'HeatingQC_Ex', 'ExterQual_Gd', 'Neighborhood_NridgHt', 'BsmtQual_Ex', 'ExterQual_Ex'] not in index"

# %%
nulls_test = test.isnull().sum()
nulls_test = nulls_test[nulls_test > 0]
nulls_test
# Out:
# MSZoning           4
# LotFrontage      227
# Alley           1352
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType        16
# MasVnrArea        15
# BsmtQual          44
# BsmtCond          45
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinSF1         1
# BsmtFinType2      42
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# FireplaceQu      730
# GarageType        76
# GarageYrBlt       78
# GarageFinish      78
# GarageCars         1
# GarageArea         1
# GarageQual        78
# GarageCond        78
# PoolQC          1456
# Fence           1169
# MiscFeature     1408
# SaleType           1
# dtype: int64

# %%
test.fillna(method = 'ffill', inplace = True)

# %%
test.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 79, dtype: int64

# %%
test_dummy = pd.get_dummies(data = test)
test_dummy
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461          20         80.0    11622            5            6       1961
# 1462          20         81.0    14267            6            6       1958
# 1463          60         74.0    13830            5            5       1997
# 1464          60         78.0     9978            6            6       1998
# 1465         120         43.0     5005            8            5       1992
# ...          ...          ...      ...          ...          ...        ...
# 2915         160         21.0     1936            4            7       1970
# 2916         160         21.0     1894            4            5       1970
# 2917          20        160.0    20000            5            7       1960
# 2918          85         62.0    10441            5            5       1992
# 2919          60         74.0     9627            7            5       1993
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLw  \
# Id                                                      ...
# 1461          1961         0.0       468.0       144.0  ...               0
# 1462          1958       108.0       923.0         0.0  ...               0
# 1463          1998         0.0       791.0         0.0  ...               0
# 1464          1998        20.0       602.0         0.0  ...               0
# 1465          1992         0.0       263.0         0.0  ...               0
# ...            ...         ...         ...         ...  ...             ...
# 2915          1970         0.0         0.0         0.0  ...               0
# 2916          1970         0.0       252.0         0.0  ...               0
# 2917          1996         0.0      1224.0         0.0  ...               0
# 2918          1992         0.0       337.0         0.0  ...               0
# 2919          1994        94.0       758.0         0.0  ...               0
#
#       SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# Id
# 1461             0             0            1                      0
# 1462             0             0            1                      0
# 1463             0             0            1                      0
# 1464             0             0            1                      0
# 1465             0             0            1                      0
# ...            ...           ...          ...                    ...
# 2915             0             0            1                      0
# 2916             0             0            1                      1
# 2917             0             0            1                      1
# 2918             0             0            1                      0
# 2919             0             0            1                      0
#
#       SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# Id
# 1461                      0                     0                     0
# 1462                      0                     0                     0
# 1463                      0                     0                     0
# 1464                      0                     0                     0
# 1465                      0                     0                     0
# ...                     ...                   ...                   ...
# 2915                      0                     0                     0
# 2916                      0                     0                     0
# 2917                      0                     0                     0
# 2918                      0                     0                     0
# 2919                      0                     0                     0
#
#       SaleCondition_Normal  SaleCondition_Partial
# Id
# 1461                     1                      0
# 1462                     1                      0
# 1463                     1                      0
# 1464                     1                      0
# 1465                     1                      0
# ...                    ...                    ...
# 2915                     1                      0
# 2916                     0                      0
# 2917                     0                      0
# 2918                     1                      0
# 2919                     1                      0
#
# [1459 rows x 270 columns]

# %%
test_dummy = test_dummy[['OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'TotalBsmtSF',
       '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'Fireplaces',
       'GarageCars', 'GarageArea', 'Neighborhood_NridgHt',
       'ExterQual_Ex', 'ExterQual_Gd', 'ExterQual_TA', 'Foundation_PConc',
       'BsmtQual_Ex', 'BsmtQual_TA', 'BsmtFinType1_GLQ', 'HeatingQC_Ex',
       'KitchenQual_Ex', 'KitchenQual_TA',
       'GarageFinish_Fin', 'GarageFinish_Unf']]

# %%
predicted = linreg.predict(test_dummy)

# %%
df_pred = pd.DataFrame({'SalePrice':predicted})
df_pred.set_index([pd.Index(np.arange(1461,2920))], inplace = True)
df_pred.index.name = 'Id'
df_pred
# Out:
#           SalePrice
# Id
# 1461  101446.252952
# 1462  143371.129280
# 1463  179757.722073
# 1464  199598.119059
# 1465  191806.901039
# ...             ...
# 2915   78964.858370
# 2916   92000.037024
# 2917  151279.558043
# 2918  107652.578600
# 2919  223055.202710
#
# [1459 rows x 1 columns]

# %%
df_pred.to_csv(r'./cabo_submission_2.csv')
