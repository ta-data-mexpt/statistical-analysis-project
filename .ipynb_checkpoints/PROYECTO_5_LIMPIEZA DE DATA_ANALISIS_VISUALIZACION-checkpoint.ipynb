# %% [markdown]
# # Importación de librerias

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.datasets import load_boston
from  sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import r2_score
from scipy.stats import linregress
import scipy.stats as stats
from statsmodels.stats.proportion import proportions_ztest
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Limpieza de datos

# %%
data_original = pd.read_csv('/Users/user/statistical-analysis-project/train.csv')

# %%
data_original.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
data_original.shape
# Out:
# (1460, 81)

# %%
data_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data = data_original.drop(['PoolQC','Fence','MiscFeature','Alley'], axis=1).reset_index(drop=True)

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
#visualizar todas las columnas sin limitación 
pd.options.display.max_columns = None
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
data['BsmtFullBath'].value_counts()
# Out:
# 0    856
# 1    588
# 2     15
# 3      1
# Name: BsmtFullBath, dtype: int64

# %%
data['CentralAir'] = data['CentralAir'].replace({"N":0 , "Y":1})

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %% [markdown]
# ## Comenzamos a calcular

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
data_numerico = data._get_numeric_data()

# %%
data_numerico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 39 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   OverallQual    1460 non-null   int64
#  5   OverallCond    1460 non-null   int64
#  6   YearBuilt      1460 non-null   int64
#  7   YearRemodAdd   1460 non-null   int64
#  8   MasVnrArea     1452 non-null   float64
#  9   BsmtFinSF1     1460 non-null   int64
#  10  BsmtFinSF2     1460 non-null   int64
#  11  BsmtUnfSF      1460 non-null   int64
#  12  TotalBsmtSF    1460 non-null   int64
#  13  CentralAir     1460 non-null   int64
#  14  1stFlrSF       1460 non-null   int64
#  15  2ndFlrSF       1460 non-null   int64
#  16  LowQualFinSF   1460 non-null   int64
#  17  GrLivArea      1460 non-null   int64
# ...

# %% [markdown]
# # Análisis de información

# %%
#se sacó la correlacion de todas las colummnas numéricas con la de "SalesPrice"

# %%
data_numerico.corr()['SalePrice']
# Out:
# Id              -0.021917
# MSSubClass      -0.084284
# LotFrontage      0.351799
# LotArea          0.263843
# OverallQual      0.790982
# OverallCond     -0.077856
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.477493
# BsmtFinSF1       0.386420
# BsmtFinSF2      -0.011378
# BsmtUnfSF        0.214479
# TotalBsmtSF      0.613581
# CentralAir       0.251328
# 1stFlrSF         0.605852
# 2ndFlrSF         0.319334
# LowQualFinSF    -0.025606
# GrLivArea        0.708624
# BsmtFullBath     0.227122
# BsmtHalfBath    -0.016844
# FullBath         0.560664
# HalfBath         0.284108
# BedroomAbvGr     0.168213
# KitchenAbvGr    -0.135907
# TotRmsAbvGrd     0.533723
# Fireplaces       0.466929
# GarageYrBlt      0.486362
# GarageCars       0.640409
# GarageArea       0.623431
# WoodDeckSF       0.324413
# OpenPorchSF      0.315856
# EnclosedPorch   -0.128578
# 3SsnPorch        0.044584
# ScreenPorch      0.111447
# PoolArea         0.092404
# ...

# %% [markdown]
# Se intentó generar un heatmap para poder ver la correlacion, pero debido a que son tantas variables no era legible

# %%
#mask = np.zeros_like(data_numerico.corr(),dtype=np.bool)
#mask[np.triu_indices_from(mask)]=True

#plt.subplots(figsize=(70,70))
#cmap = sns.diverging_palette(6,255,as_cmap=True)
#sns.heatmap(data_numerico.corr(),mask=mask,cmap=cmap,linewidths=.5,annot=True)

# %%
#sns.pairplot(data_numerico)
#sns.plt.show()

# %% [markdown]
# Debido a que en lista, identificacmos que "OverllQual" era la variable con mayor relacion, se hizo un scatter de ambas
# variables, donde podemos afirmar la correlacion positiva: Cuando una variable aumenta, la otra tambien.
# * OverllQual mide del 1 al 10 la calificación de los inmuebles

# %%
plt.scatter(data_numerico.OverallQual, data_numerico.SalePrice, c = 'b');

# %% [markdown]
# # Regresión lineal

# %% [markdown]
# Ahora se hará una regresión lineal donde tambien por medio de la R-square y del Pvalue podremos saber si la variable
# de OverallQual afecta la variable del precio

# %%
X = sm.add_constant(data_numerico['OverallQual']) 
Y = data_numerico['SalePrice']

model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.626
# Model:                            OLS   Adj. R-squared:                  0.625
# Method:                 Least Squares   F-statistic:                     2437.
# Date:                Mon, 25 Jan 2021   Prob (F-statistic):          2.19e-313
# Time:                        21:40:27   Log-Likelihood:                -17827.
# No. Observations:                1460   AIC:                         3.566e+04
# Df Residuals:                    1458   BIC:                         3.567e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -9.621e+04   5756.407    -16.713      0.000   -1.07e+05   -8.49e+04
# ...

# %%
#En este ejercicio mi R al cuadrado esta arriba del .5 por lo tanto la curva si se ajusta a los datos 
#Como el P-Value es muy pequeño rechazamos la hipótesis nula : Prob (F-statistic):2.19e-313
#Lo que podemos deducir es que la variable, en este caso el OverallQual, si afecta el precio

# %% [markdown]
# Ahora se graficará la regresión lineal, primero poniendo en eje "x" las calificaciones y en "y" los costos y viceversa, esto por que ya no se tendrá calificaciones arrriba de 10, po lo que cambair los ejes nos pueden dar
# costos estimados

# %%
#Aqui se realiza con sns.lmplot

sns.lmplot(data = data_numerico, x = 'OverallQual', y = 'SalePrice',  height = 6, aspect = 2)

# %%
#aqui se usa el modelo linregress
slope, intercept, r_value, p_value, std_err = linregress(data_numerico['OverallQual'], data_numerico['SalePrice'])
print(f'Slope: {slope}\nIntercept: {intercept}\nR_value: {r_value}\nP_value: {p_value}\nStd_err: {std_err}')
# Out:
# Slope: 45435.80259309941
# Intercept: -96206.07951476044
# R_value: 0.7909816005838054
# P_value: 2.185675268e-313
# Std_err: 920.4302464882167

# %%
#aqui pusimos en eje x overllqual y en eje y el costo
evaluacion = range(0, max(data_numerico['OverallQual']+4))
precio = [(slope * eva + intercept) for eva in evaluacion]
fig =  plt.figure(facecolor = 'w', figsize = (12, 8))
plt.scatter(data = data_numerico, x = 'OverallQual', y = 'SalePrice')
plt.plot(evaluacion,precio)
plt.xlabel('Evaluacion de casas 1-10')
plt.ylabel('Precio de las casas');

# %% [markdown]
# Ahora generamos un boxplot, lo cual nos dara la mediana, los rangos del cuartil 50, y la desviacion estandar de los
# costos según sea la calificación asignada

# %%
plt.figure(figsize=(30,20))
sns.boxplot(data_numerico['OverallQual'], data_numerico['SalePrice'])
# Out:
# /usr/local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %% [markdown]
# Aqui armamos tablas por cada uno de los niveles ya que más adelante serán ocupados para hacer las comparaciones y modelos predictivos

# %%
calificacion1 = data_numerico[data_numerico['OverallQual']==1].reset_index(drop=True)
calificacion2 = data_numerico[data_numerico['OverallQual']==2].reset_index(drop=True)
calificacion3 = data_numerico[data_numerico['OverallQual']==3].reset_index(drop=True)
calificacion4 = data_numerico[data_numerico['OverallQual']==4].reset_index(drop=True)
calificacion5 = data_numerico[data_numerico['OverallQual']==5].reset_index(drop=True)
calificacion6 = data_numerico[data_numerico['OverallQual']==6].reset_index(drop=True)
calificacion7 = data_numerico[data_numerico['OverallQual']==7].reset_index(drop=True)
calificacion8 = data_numerico[data_numerico['OverallQual']==8].reset_index(drop=True)
calificacion9 = data_numerico[data_numerico['OverallQual']==9].reset_index(drop=True)
calificacion10 = data_numerico[data_numerico['OverallQual']==10].reset_index(drop=True)

# %% [markdown]
# # Sacaremos el intervalo de costo por tipo de calificación

# %% [markdown]
# Hipotesis 2 colas
#
# * hipotesis nula = Ypoblacional = y muestral
# * hipotesis alternativa  = y poblacional != y muestral
#
# Hipotesis de 1 cola
#
# * hipotesis nula = Ypoblacional = y muestral
# * hipotesis alternativa  =   y muestral > "o" < y poblacional

# %% [markdown]
# Aqui armamos tablas por cada uno de los niveles ya que más adelante serán ocupados para hacer las comparaciones y modelos predictivos

# %%
calificacion1 = data_numerico[data_numerico['OverallQual']==1].reset_index(drop=True)
calificacion2 = data_numerico[data_numerico['OverallQual']==2].reset_index(drop=True)
calificacion3 = data_numerico[data_numerico['OverallQual']==3].reset_index(drop=True)
calificacion4 = data_numerico[data_numerico['OverallQual']==4].reset_index(drop=True)
calificacion5 = data_numerico[data_numerico['OverallQual']==5].reset_index(drop=True)
calificacion6 = data_numerico[data_numerico['OverallQual']==6].reset_index(drop=True)
calificacion7 = data_numerico[data_numerico['OverallQual']==7].reset_index(drop=True)
calificacion8 = data_numerico[data_numerico['OverallQual']==8].reset_index(drop=True)
calificacion9 = data_numerico[data_numerico['OverallQual']==9].reset_index(drop=True)
calificacion10 = data_numerico[data_numerico['OverallQual']==10].reset_index(drop=True)

# %%
#Sacamos la media la columna de precios
data_numerico.SalePrice.mean()
# Out:
# 180921.19589041095

# %%
#Sacamos la media de la columna de precios pero solo de la categoría calificaad como 10
calificacion10.SalePrice.mean()
# Out:
# 438588.3888888889

# %%
calificacion10.SalePrice.std()
# Out:
# 159785.49105786977

# %%
calificacion10.SalePrice.mean()-calificacion10.SalePrice.std()
# Out:
# 278802.89783101913

# %%
calificacion10.SalePrice.mean()+calificacion10.SalePrice.std()
# Out:
# 598373.8799467586

# %% [markdown]
#  * Hipótesis nula = el promedio de costo de calificacion10 es igual al promedio
#    de todas las calificaciones
#  * Hipótesis alternativa = el promedio de calificación10 es mayor o menor al promedio de
#    todas las calificaciones

# %%
#que yo le ponga mayor o menor es porque yo ya tengo conocimiento previo
#esto se convierte en una hipotesis de una cola
#aqui utilizamos el modelo lsamp para comparar las medias 
t, p = stats.ttest_1samp(calificacion10['SalePrice'],180921)
stats.ttest_1samp(calificacion10['SalePrice'],180921)
# Out:
# Ttest_1sampResult(statistic=6.841610840923379, pvalue=2.8644026559780906e-06)

# %%
#Debido a que es una hipótesis de una cola, el p-value se divide en dos
cola = p/2
cola
# Out:
# 1.4322013279890453e-06

# %% [markdown]
# * La hipotesis SE RECHAZA ya que p-value es menor que 0.05
# * Comprobamos que nuestro promedio de menor o mayor (en este caso mayor, por el conocimiento     previo)

# %% [markdown]
# Ahora sacaremos el intervalo de costos de cada una de las calificaciones predeterminadas
# para cada calificación de un inmueble ( de 1 a 10), esto nos servirá estadísticamente al
# decir que, si del grupo de calificacion 5, por poner un ejemplo, se toma una muestra de 10 inmuebles,
# el promedio de costo de esos 10 inmuebles será con "tales" intervalos de costo.
#
# Esto puede ser como un refente cuando una persona quisiera comprar una casa con cierto
# tipo de calificación.

# %%
#Debido a que dentro de calificaicon solo tengo 2 datos, no podré sacar el intervalo de costo
calificacion1.SalePrice.value_counts()
# Out:
# 39300    1
# 61000    1
# Name: SalePrice, dtype: int64

# %%
#Debido a que dentro de calificaicon solo tengo 3 datos, no podré sacar el intervalo de costo
calificacion2.SalePrice.value_counts()
# Out:
# 60000    2
# 35311    1
# Name: SalePrice, dtype: int64

# %% [markdown]
# Ahora sacamos el costo del resto de los datos

# %%
calificacion3_inter = (calificacion3['SalePrice'].quantile(.25), '|', calificacion3['SalePrice'].quantile(.75))

# %%
calificacion4_inter= (calificacion4['SalePrice'].quantile(.25), '|', calificacion4['SalePrice'].quantile(.75))

# %%
calificacion5_inter =(calificacion5['SalePrice'].quantile(.25), '|', calificacion5['SalePrice'].quantile(.75))

# %%
calificacion6_inter =(calificacion6['SalePrice'].quantile(.25), '|', calificacion6['SalePrice'].quantile(.75))

# %%
calificacion7_inter =(calificacion7['SalePrice'].quantile(.25), '|', calificacion7['SalePrice'].quantile(.75))

# %%
calificacion8_inter= (calificacion8['SalePrice'].quantile(.25), '|', calificacion8['SalePrice'].quantile(.75))

# %%
calificacion9_inter= (calificacion9['SalePrice'].quantile(.25), '|', calificacion9['SalePrice'].quantile(.75))

# %%
calificacion10_inter =(calificacion10['SalePrice'].quantile(.25), '|', calificacion10['SalePrice'].quantile(.75))

# %%
Calificaciones =[3,4,5,6,7,8,9,10]
Intervalo_menor = [calificacion3_inter[0],calificacion4_inter[0],calificacion5_inter[0],calificacion6_inter[0],calificacion7_inter[0],calificacion8_inter[0],calificacion9_inter[0],calificacion10_inter[0]]
Intervalo_mayor = [calificacion3_inter[2],calificacion4_inter[2],calificacion5_inter[2],calificacion6_inter[2],calificacion7_inter[2],calificacion8_inter[2],calificacion9_inter[2],calificacion10_inter[2]]
invervalos_costos_cali = pd.DataFrame(Calificaciones)
invervalos_costos_cali['Intervalo_menor'] = Intervalo_menor
invervalos_costos_cali['Intervalo_mayor'] = Intervalo_mayor

# %%
invervalos_costos_cali.columns = ['Calificaciones','Intervalo_menor','Intervalo_mayor']
invervalos_costos_cali
# Out:
#    Calificaciones  Intervalo_menor  Intervalo_mayor
# 0               3          75500.0          97500.0
# 1               4          88000.0         125500.0
# 2               5         118000.0         147000.0
# 3               6         139125.0         181000.0
# 4               7         179470.0         230750.0
# 5               8         234557.5         306250.0
# 6               9         318980.5         389716.0
# 7              10         349375.0         472875.0

# %% [markdown]
# # Pero ¿Podemos predecir el costo de un inmueble?

# %% [markdown]
# Si bien anteriormente sacamos un intervalo del percentil 50 de cada una de las calificaciones de calidad de materiales, la cual vimos que es la variable que más correlación tiene con el costo, ¿Qué pasaría si un comprador supiera específicamente las características de la casa que dese acomprar?
#
#
# En las siguientes lineas crearemos dos moddelos predictivos que nos ayudarán a determinar el costo de una casa según las características que se deseen y de esta forma "predecir" un costo.
#
# Para lo anterior será muy importante convertir variables categóricas en numéricas para ver la influencia que ejercen en el costo

# %%
#creo una data donde variables categóricas las hago numéricas
data_categorias_evaluacion = data
data_categorias_evaluacion = data_categorias_evaluacion.replace({"Ex":5 ,"Gd": 4, "TA":3,"Fa":2 ,"Po":1,"NA":0})

# %%
data_categorias_evaluacion =  data_categorias_evaluacion._get_numeric_data()
#data_categorias_evaluacion[['SalePrice','OverallQual','OverallCond','ExterQual','ExterCond','BsmtQual','BsmtCond','HeatingQC','KitchenQual','FireplaceQu','GarageQual','GarageCond']]
#las variables que daban una calificacion del 1 al 5 (o no lo tiene) por la condicion del inmueble son las siguientes:
#ExterQual,ExterCond,BsmtQual,BsmtCond,HeatingQC,KitchenQual, FireplaceQu,GarageQual,GarageCond
#Estas son las variables que veremos si tienen mayor correlacion con el tipo de calificación y costo

# %%
data_categorias_evaluacion.corr()['SalePrice']
# Out:
# Id              -0.021917
# MSSubClass      -0.084284
# LotFrontage      0.351799
# LotArea          0.263843
# OverallQual      0.790982
# OverallCond     -0.077856
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.477493
# ExterQual        0.682639
# ExterCond        0.018899
# BsmtQual         0.644019
# BsmtCond         0.160658
# BsmtFinSF1       0.386420
# BsmtFinSF2      -0.011378
# BsmtUnfSF        0.214479
# TotalBsmtSF      0.613581
# HeatingQC        0.427649
# CentralAir       0.251328
# 1stFlrSF         0.605852
# 2ndFlrSF         0.319334
# LowQualFinSF    -0.025606
# GrLivArea        0.708624
# BsmtFullBath     0.227122
# BsmtHalfBath    -0.016844
# FullBath         0.560664
# HalfBath         0.284108
# BedroomAbvGr     0.168213
# KitchenAbvGr    -0.135907
# KitchenQual      0.659600
# TotRmsAbvGrd     0.533723
# Fireplaces       0.466929
# FireplaceQu      0.295794
# GarageYrBlt      0.486362
# GarageCars       0.640409
# ...

# %%
data_prueba= data_categorias_evaluacion.dropna()

# %%
data_prueba.shape
# Out:
# (585, 48)

# %% [markdown]
# ## Modelo de predicción

# %% [markdown]
# * Anteriormente por medio de la correlación podemos definir las siguientes variables como las más relevantes que afectan el costo, por lo que serán las variables que usaremos para los modelos

# %%
#r-ajustada penaliza las columnas que no aportan
#ahora haremos una regresesión lineal para determinar otra forma de sacar
#los intervalos de costo

x = data_prueba[['ExterQual','BsmtQual','FullBath','KitchenQual','GrLivArea','TotalBsmtSF','TotRmsAbvGrd','1stFlrSF','GarageCars',]]
y = data_prueba.SalePrice

# %%
#Crear nuestros Datasets de entrenamiento y de prueba
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size =.2, random_state=77)

# %%
print(len(x))
print(len(y))
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 585
# 585
# 468
# 117
# 468
# 117

# %%
#Modelo de regresión lineal

linreg = LinearRegression()
linreg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
coeff_df = pd.DataFrame(linreg.coef_, x.columns, columns=['Coefficient'])
coeff_df
# Out:
#                Coefficient
# ExterQual     21568.228630
# BsmtQual      20150.576495
# FullBath      -7749.717479
# KitchenQual   16464.512418
# GrLivArea        61.708121
# TotalBsmtSF      51.312366
# TotRmsAbvGrd   3290.011280
# 1stFlrSF         -0.953121
# GarageCars    14513.841533

# %%
#Obtener nuestro coeficiente de Determination R^2
train_score = linreg.score(x_train,y_train)
test_score = linreg.score(x_test,y_test)

# %%
train_score
# Out:
# 0.7683246860713573

# %%
predicted = linreg.predict(x_test)

# %%
#Con r2_score podemos calcular el error de nuestro modelo

r2_score(y_test,predicted)
# Out:
# 0.4618754516408864

# %%
data_categorias_pred = pd.DataFrame({'Actual': y_test, 'Predicted':predicted})

# %%
data_categorias_pred
# Out:
#       Actual      Predicted
# 599   151000  158258.191514
# 286   159000  186301.423978
# 998    91000  116373.122860
# 326   324000  264609.397004
# 558   175000  152124.968368
# 556   141000  121645.999004
# 1328  256000  302592.390513
# 595   319000  286038.992180
# 1375  239000  258077.562067
# 1095  176432  211472.396010
# 1063  110500  150567.082709
# 243   120000  126042.682267
# 40    160000  142300.033679
# 718   341000  303817.615805
# 832   237000  227758.091171
# 1075  219500  146775.462553
# 503   289000  192472.176152
# 425   135000  117711.508994
# 765   264132  249043.343905
# 947   270000  270490.431134
# 964   214900  228807.912048
# 201   171500  145107.794226
# 642   345000  355664.679599
# 317   270000  260986.808829
# 1224  184000  202424.084795
# 377   340000  294786.016055
# 902   180000  203321.867970
# 1399  137450  159475.149070
# 9     118000  112262.113718
# 34    277500  297336.353129
# 445   127500  193372.041058
# 1107  274725  262642.315289
# ...

# %% [markdown]
# ## Ahora lo hacemos con modelo Ridge

# %% [markdown]
# El objetivo de hacerlo con otro modelo es para podeer comprobar el error
# de nuestra predicción a pesar de haberlo intentado con distintos modelos

# %%
#Regresióon Ridge
rr = Ridge()
rr.fit(x_train,y_train)
# Out:
# Ridge()

# %%
rr100 = Ridge(alpha=100)
rr100.fit(x_train,y_train)
# Out:
# Ridge(alpha=100)

# %%
#Obtenemos R^2 de nuestros Ridge
ridge_train_score = rr.score(x_train,y_train)
ridge_test_score = rr.score(x_test,y_test)
ridge_train_score100 = rr100.score(x_train,y_train)
ridge_test_score100 = rr100.score(x_test,y_test)

# %%
predicted_ridge = rr100.predict(x_test)

# %%
#Con r2_score podemos calcular el error de nuestro modelo

r2_score(y_test,predicted_ridge)
# Out:
# 0.39614065799621645

# %%
datacateg_predic_ridge = pd.DataFrame({'Actual':y_test, 'Predicted':predicted_ridge})
datacateg_predic_ridge
# Out:
#       Actual      Predicted
# 599   151000  160537.928557
# 286   159000  185501.485019
# 998    91000  121563.199163
# 326   324000  260982.334854
# 558   175000  154182.884814
# 556   141000  128153.638969
# 1328  256000  309483.719368
# 595   319000  286643.228609
# 1375  239000  255416.850206
# 1095  176432  209349.674484
# 1063  110500  150578.888057
# 243   120000  123367.776264
# 40    160000  151124.406965
# 718   341000  301222.816006
# 832   237000  223496.586619
# 1075  219500  151471.172944
# 503   289000  206742.476734
# 425   135000  120316.736508
# 765   264132  246857.558021
# 947   270000  268494.840998
# 964   214900  223481.220275
# 201   171500  155757.770312
# 642   345000  361944.271597
# 317   270000  254641.495852
# 1224  184000  195530.133543
# 377   340000  306214.510417
# 902   180000  196303.384134
# 1399  137450  169923.457013
# 9     118000  117154.501910
# 34    277500  283992.921805
# 445   127500  199922.350039
# 1107  274725  253449.210433
# ...

# %%
print(train_score)
print(test_score)
print(ridge_train_score)
print(ridge_test_score)
print(ridge_train_score100)
print(ridge_test_score100)
# Out:
# 0.7683246860713573
# 0.4618754516408864
# 0.7683228759215572
# 0.4612262743764435
# 0.7615354345201433
# 0.39614065799621645

# %%
#Train Score alto significa que mis datos se ajustan a las datos de la data
#Test score bajo significa que hay Overfitting

# %%
fig = plt.figure(facecolor='w',figsize=(12, 12))
#Agui graficamos los coeficientes de Ridge con Alpha de 1
plt.plot(rr.coef_,alpha=0.7,linestyle='none',marker='*',markersize=9,\
         color='red',label=r'Ridge; $\alpha = 0.01$',zorder=7)
#Aqui graficamos los coeficientes de Ridge con Alpha de 100
plt.plot(rr100.coef_,alpha=0.5,linestyle='none',marker='d',markersize=10,\
         color='blue',label=r'Ridge; $\alpha = 100$')
#Aqui graficamos los coeficientes de Regresión lineal
plt.plot(linreg.coef_,alpha=0.4,linestyle='none',marker='o',markersize=14,\
         color='green',label='Linear Regression')
plt.xlabel('Coefficient Index',fontsize=16)
plt.ylabel('Coefficient Magnitude',fontsize=16)
plt.legend(fontsize=13,loc=4)
plt.show()

# %%
#aqui podemos observar que los datos de mi regresión lineal, estamuy cerca
#de los datos con alpha 0.01

# %% [markdown]
# ## Hagamos una prueba...

# %% [markdown]
# * Ahora crearemos un diccionario que pueda preguntarle a cualquier usuario cómo desaría que fuera la casa su casa que le intersa adquirir, donde responderá principalmente a estas 9 variables las cuales encontramos, son las que en su mayoria determinan el costo:

# %%
# ExterQual de 1 a 5 calidad de materiales del exterior
# BsmtQual de 1 a 5  calidad de materiales del sótano
# FullBath < data_prueba.FullBath.max()  baños completos
# KitchenQual de 1 a 5  calidad de materiales de la cocina
# GrLivArea < data_prueba.GrLivArea.max() cantidad de pies cuadrados de la sala
# TotalBsmtSF < data_prueba.TotalBsmtSF.max() pies cuadrados del sótano
# TotRmsAbvGrd < data_prueba.TotRmsAbvGrd.max() cuartos por arriba del sótano
# 1stFlrSF < data_prueba.1stFlrSF.max() pies cuadrados primer piso
# GarageCars < data_prueba.GarageCars.max() capacidad de autos garage

comprador = pd.DataFrame({
    'ExterQual':[3],
    'BsmtQual': [4], 
    'FullBath': [2],
    'KitchenQual': [3], 
    'GrLivArea': [100],
    'TotalBsmtSF':[4] ,
    'TotRmsAbvGrd':[100],
    '1stFlrSF':[200],
    'GarageCars':[3]})
comprador
# Out:
#    ExterQual  BsmtQual  FullBath  KitchenQual  GrLivArea  TotalBsmtSF  \
# 0          3         4         2            3        100            4
#
#    TotRmsAbvGrd  1stFlrSF  GarageCars
# 0           100       200           3

# %%
#Ahora predecimos el costo con el modelo linreg.predict
predicted_comprador = linreg.predict(comprador)
predicted_comprador
# Out:
# array([356143.47440923])

# %%
#Aqui utilizamos el modelo Ridge
predicted_ridge_comprador = rr100.predict(comprador)
predicted_ridge_comprador
# Out:
# array([345246.02441732])

# %% [markdown]
# El costo de la casa con las características dadas seria de:
#
# * Modelo 1: 356,143 aprox, con un error de cálculo de 0.4618754516408864 (r2_score)
#
# * Modelo Ridge: 345,246 aprox, con un error de cálculo de 0.39614065799621645 (r2_score)

# %% [markdown]
# # Sugerencias de costo

# %% [markdown]
# Confirmaremos si la media de costo entre cada uno de los niveles de calificación de las casas no tiene mucha variación, para así poder encontrar qué determina la calificación de cada nivel
# y si al cliente le conviene comprar mejor una casa de tal o tal nivel
#
# ** Armaremos el modelo de ttest para poder comparar las medias de los costos entre cada nivel
#
# HIPOTESIS NULA: la media del grupo 1 es igual a la media del grupo 2, y así consecutivamente

# %%
stats.ttest_ind(calificacion1.SalePrice,calificacion2.SalePrice)
# Out:
# Ttest_indResult(statistic=-0.12135356879272774, pvalue=0.9110830181817464)

# %%
stats.ttest_ind(calificacion2.SalePrice,calificacion3.SalePrice)
# Out:
# Ttest_indResult(statistic=-2.413623949237954, pvalue=0.025011791614114792)

# %%
stats.ttest_ind(calificacion3.SalePrice,calificacion4.SalePrice)
# Out:
# Ttest_indResult(statistic=-3.0412101825283737, pvalue=0.00283518394192322)

# %%
stats.ttest_ind(calificacion4.SalePrice,calificacion5.SalePrice)
# Out:
# Ttest_indResult(statistic=-8.633102856017272, pvalue=7.623349134706355e-17)

# %%
stats.ttest_ind(calificacion5.SalePrice,calificacion6.SalePrice)
# Out:
# Ttest_indResult(statistic=-12.260269587247109, pvalue=1.0864556787284587e-31)

# %%
stats.ttest_ind(calificacion6.SalePrice,calificacion7.SalePrice)
# Out:
# Ttest_indResult(statistic=-15.065080963057685, pvalue=1.4729852688407912e-44)

# %%
stats.ttest_ind(calificacion7.SalePrice,calificacion8.SalePrice)
# Out:
# Ttest_indResult(statistic=-13.52426699069019, pvalue=1.3698976812757618e-35)

# %%
stats.ttest_ind(calificacion8.SalePrice,calificacion9.SalePrice)
# Out:
# Ttest_indResult(statistic=-8.012706669656426, pvalue=7.795203708504397e-14)

# %%
stats.ttest_ind(calificacion9.SalePrice,calificacion10.SalePrice)
# Out:
# Ttest_indResult(statistic=-2.3055031502078016, pvalue=0.024672157209085104)

# %% [markdown]
# * Ninguna media del rango de calificaciones fue igual, solo la calificacion 1 y la 2 fueron con las que pudimos  aceptar la hipotesis nula

# %% [markdown]
# # Pero ¿Qué determina la calificación de un inmueble?

# %% [markdown]
# Tenemos claro que los costos y las calificaciones están correlacionados, pero podemos observar con los outlayers que existen precios casi a la misma altura que otra calificación.
#
# Esto es porque la variable que conjunta las condiciones de la casa: OverallCond, tiene una correlacion negativa con la variable del precio aunque esta es muy pequeña:  -0.077856
#
# Al haber convertido las clolumnas categoricas en numéricas del 0 al 6 para poder hacer otro tipo de correlacion, confirmaremos si estas variables puede influir en el costo, es decir, para una característica en estado muy malo a uno medio ¿Qué tanto influye en el costo en la calificación?

# %%
data_categorias_evaluacion.corr()['OverallQual']
# Out:
# Id              -0.028365
# MSSubClass       0.032628
# LotFrontage      0.251646
# LotArea          0.105806
# OverallQual      1.000000
# OverallCond     -0.091932
# YearBuilt        0.572323
# YearRemodAdd     0.550684
# MasVnrArea       0.411876
# ExterQual        0.726278
# ExterCond        0.013953
# BsmtQual         0.664650
# BsmtCond         0.177320
# BsmtFinSF1       0.239666
# BsmtFinSF2      -0.059119
# BsmtUnfSF        0.308159
# TotalBsmtSF      0.537808
# HeatingQC        0.457083
# 1stFlrSF         0.476224
# 2ndFlrSF         0.295493
# LowQualFinSF    -0.030429
# GrLivArea        0.593007
# BsmtFullBath     0.111098
# BsmtHalfBath    -0.040150
# FullBath         0.550600
# HalfBath         0.273458
# BedroomAbvGr     0.101676
# KitchenAbvGr    -0.183882
# KitchenQual      0.673331
# TotRmsAbvGrd     0.427452
# Fireplaces       0.396765
# FireplaceQu      0.355867
# GarageYrBlt      0.547766
# GarageCars       0.600671
# GarageArea       0.562022
# ...

# %% [markdown]
# Se detectaron 2 variables importantes que de forma lógica parecerían tener toda la influencia de los ctos de la casa: OverallCond y OverallQual.
#
# Por lo anterior se decidió comprobarlo:

# %%
fig =  plt.figure(figsize = (12,10))
sns.scatterplot(data=data_categorias_evaluacion, x="OverallCond", y="SalePrice", hue = 'OverallQual')
plt.xlabel('Evaluacion de Condiciones del inmueble')
plt.ylabel('Precio');

# %% [markdown]
# * Nos pudimos percatar que dentro de variable de OverallCond ningun inmueble está con calificacion 10, la cual es que   la condición del inmueble es excelentes condiciones.
#
#
#
# * A pesar de lo anterior pudimos percatarnos que los inmuebles con calificación de condición "5" tienen costos muy       elevados, donde cruzándolo con una tercera variable "OverallQual" donde descubrimos que inmuebles en condición 5,     cruza con evaluaciones de calidad de material del inmueble arriba de   8, la cual es la variable que determina el     costo del inmueble:

# %% [markdown]
# Para tratar de disernir esta incognita, se hacen los filtros adecuados en la siguiente parte, donde solo se toma de   OverallCond igual a 5 y con OverallQual arriba de 8:

# %%
OverallCond5 = data_categorias_evaluacion[data_categorias_evaluacion['OverallCond']==5].reset_index(drop=True)

# %%
OverallCond5 = OverallCond5[OverallCond5['OverallQual']>8]

# %%
#Con este método puedo observar todas las filas de mi tabla
pd.options.display.max_rows = None
OverallCond5.sort_values('SalePrice',ascending=False)
# Out:
#        Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 663  1183          60        160.0    15623           10            5
# 656  1170          60        118.0    35760           10            5
# 510   899          20        100.0    12919            9            5
# 459   804          60        107.0    13891            9            5
# 591  1047          60         85.0    16056            9            5
# 251   441          20        105.0    15431           10            5
# 108   179          20         63.0    17423            9            5
# 456   799          60        104.0    13518            9            5
# 774  1374          20          NaN    11400           10            5
# 701  1244          20        107.0    13891           10            5
# 332   592          60         97.0    13478           10            5
# 297   528          60         67.0    14948            9            5
# ...

# %%
OverallCond5.corr()['SalePrice']
# Out:
# Id               0.068490
# MSSubClass      -0.092738
# LotFrontage     -0.068265
# LotArea         -0.090938
# OverallQual      0.234148
# OverallCond           NaN
# YearBuilt       -0.157205
# YearRemodAdd    -0.153790
# MasVnrArea       0.199654
# ExterQual        0.049245
# ExterCond        0.310196
# BsmtQual         0.189485
# BsmtCond        -0.048164
# BsmtFinSF1      -0.009352
# BsmtFinSF2       0.221005
# BsmtUnfSF       -0.051963
# TotalBsmtSF     -0.038649
# HeatingQC       -0.004399
# 1stFlrSF         0.006460
# 2ndFlrSF         0.301660
# LowQualFinSF          NaN
# GrLivArea        0.236079
# BsmtFullBath    -0.025372
# BsmtHalfBath          NaN
# FullBath         0.303655
# HalfBath         0.359804
# BedroomAbvGr     0.194269
# KitchenAbvGr          NaN
# KitchenQual      0.025838
# TotRmsAbvGrd     0.363687
# Fireplaces       0.169970
# FireplaceQu     -0.231711
# GarageYrBlt     -0.137988
# GarageCars       0.429130
# GarageArea       0.067906
# ...

# %% [markdown]
# # Respuesta:
#
# Para los inmuebles con calificación "5" en condición y que además tuvieran calificaciones superiores a "8" en calidad de materiales, el top 5 que  determina que su costo sea más elevado (por tener correlaciones positivas) son las siguientes características:
#
# * Tamaño del garaje en capacidad de automóvil
#
# * Total de habitaciones sobre rasante (no incluye baños)
#
# * Medios baños sobre rasante
#
# * Evaluación del material en el exterior.
#
# * Baños completos sobre rasante

# %% [markdown]
# # Pero...

# %% [markdown]
# Averigüemos si los inmuebles con calificación en materiales del inmueble de 9 y 10 tienen distintas caracteristicas en el top 5 que determine el costo:

# %%
OverallCond5['SalePrice'].min()
# Out:
# 160000

# %%
Overallcond5_mayores = OverallCond5[OverallCond5['SalePrice']>250000].sort_values('SalePrice',ascending=False)

# %%
Overallcond5_mayores['OverallQual'].value_counts()
# Out:
# 9     41
# 10    13
# Name: OverallQual, dtype: int64

# %%
Overallcond5_mayores.corr()['SalePrice']
# Out:
# Id               0.141460
# MSSubClass      -0.090533
# LotFrontage      0.441915
# LotArea          0.312743
# OverallQual      0.399821
# OverallCond           NaN
# YearBuilt       -0.115436
# YearRemodAdd    -0.112075
# MasVnrArea       0.298295
# ExterQual        0.083063
# ExterCond        0.328455
# BsmtQual         0.244079
# BsmtCond        -0.083499
# BsmtFinSF1       0.318981
# BsmtFinSF2       0.229805
# BsmtUnfSF       -0.041349
# TotalBsmtSF      0.541671
# HeatingQC        0.009773
# 1stFlrSF         0.529500
# 2ndFlrSF         0.442112
# LowQualFinSF          NaN
# GrLivArea        0.792893
# BsmtFullBath     0.061134
# BsmtHalfBath          NaN
# FullBath         0.403765
# HalfBath         0.456864
# BedroomAbvGr     0.212692
# KitchenAbvGr          NaN
# KitchenQual      0.079538
# TotRmsAbvGrd     0.542905
# Fireplaces       0.285794
# FireplaceQu     -0.267011
# GarageYrBlt     -0.100036
# GarageCars       0.364298
# GarageArea       0.293592
# ...

# %% [markdown]
# # Respuesta segunda suposición
#
# Para los inmuebles con calificación "5" en condición y que además tuvieran calificaciones igual a 9 y 10 en calidad de materiales, el top 5 que determina que su costo sea más elevado (por tener correlaciones positivas) son las siguientes características:
#
# * Superficie habitable sobre el nivel (suelo) pies cuadrados (above ground y below ground)
#
# * Total de habitaciones sobre restante (no incluye baños)
#
# * Total de pies cuadrados de área del sótano (relacionada con la primera)
#
# * Pies cuadrados del primer piso
#
# * Área de la piscina en pies cuadrados (que tenga o no piscina)

# %% [markdown]
# # Ahora solo sacaremos la correlación de las variables por cada uno de las calificaciones por material

# %%
data_cat_eva_1 = data_categorias_evaluacion[data_categorias_evaluacion['OverallQual']==1].reset_index(drop=True)

# %%
data_cat_eva_1.corr()['SalePrice']
# Out:
# SalePrice      1.0
# OverallQual    NaN
# OverallCond   -1.0
# ExterQual      NaN
# ExterCond      NaN
# BsmtQual       NaN
# BsmtCond       NaN
# HeatingQC      1.0
# KitchenQual    NaN
# FireplaceQu    NaN
# GarageQual     NaN
# GarageCond     NaN
# Name: SalePrice, dtype: float64

# %%
data_cat_eva_2 = data_categorias_evaluacion[data_categorias_evaluacion['OverallQual']==2].reset_index(drop=True)

# %%
data_cat_eva_2.corr()['SalePrice']
# Out:
# SalePrice      1.0
# OverallQual    NaN
# OverallCond    0.5
# ExterQual     -0.5
# ExterCond     -0.5
# BsmtQual       NaN
# BsmtCond      -1.0
# HeatingQC     -0.5
# KitchenQual   -1.0
# FireplaceQu    NaN
# GarageQual     NaN
# GarageCond     NaN
# Name: SalePrice, dtype: float64

# %%
data_cat_eva_3 = data_categorias_evaluacion[data_categorias_evaluacion['OverallQual']==3].reset_index(drop=True)

# %%
data_cat_eva_3.corr()['SalePrice']
# Out:
# SalePrice      1.000000
# OverallQual         NaN
# OverallCond    0.282543
# ExterQual     -0.030665
# ExterCond      0.448983
# BsmtQual      -0.279968
# BsmtCond       0.132619
# HeatingQC      0.455965
# KitchenQual    0.049802
# FireplaceQu         NaN
# GarageQual    -0.274304
# GarageCond     0.599681
# Name: SalePrice, dtype: float64

# %%
data_cat_eva_4 = data_categorias_evaluacion[data_categorias_evaluacion['OverallQual']==4].reset_index(drop=True)

# %%
data_cat_eva_4.corr()['SalePrice']
# Out:
# SalePrice      1.000000
# OverallQual         NaN
# OverallCond    0.076963
# ExterQual      0.178735
# ExterCond      0.098296
# BsmtQual       0.112302
# BsmtCond       0.193783
# HeatingQC      0.375954
# KitchenQual    0.312443
# FireplaceQu    0.050532
# GarageQual     0.191029
# GarageCond     0.175855
# Name: SalePrice, dtype: float64

# %%
data_cat_eva_5 = data_categorias_evaluacion[data_categorias_evaluacion['OverallQual']==5].reset_index(drop=True)

# %%
data_cat_eva_5.corr()['SalePrice']
# Out:
# SalePrice      1.000000
# OverallQual         NaN
# OverallCond    0.127249
# ExterQual      0.169300
# ExterCond      0.138034
# BsmtQual       0.216377
# BsmtCond       0.177401
# HeatingQC      0.163441
# KitchenQual    0.224932
# FireplaceQu    0.096351
# GarageQual     0.200577
# GarageCond     0.148324
# Name: SalePrice, dtype: float64

# %%
data_cat_eva_6 = data_categorias_evaluacion[data_categorias_evaluacion['OverallQual']==6].reset_index(drop=True)

# %%
data_cat_eva_6.corr()['SalePrice']
# Out:
# SalePrice      1.000000
# OverallQual         NaN
# OverallCond    0.088114
# ExterQual      0.245237
# ExterCond      0.074109
# BsmtQual       0.334545
# BsmtCond       0.156647
# HeatingQC      0.203420
# KitchenQual    0.345202
# FireplaceQu   -0.016864
# GarageQual     0.118852
# GarageCond     0.119424
# Name: SalePrice, dtype: float64

# %%
data_cat_eva_7 = data_categorias_evaluacion[data_categorias_evaluacion['OverallQual']==7].reset_index(drop=True)

# %%
data_cat_eva_7.corr()['SalePrice']
# Out:
# SalePrice      1.000000
# OverallQual         NaN
# OverallCond    0.021618
# ExterQual      0.249271
# ExterCond     -0.018027
# BsmtQual       0.248929
# BsmtCond      -0.026133
# HeatingQC      0.043026
# KitchenQual    0.274166
# FireplaceQu    0.027325
# GarageQual     0.082556
# GarageCond     0.022373
# Name: SalePrice, dtype: float64

# %%
data_cat_eva_8 = data_categorias_evaluacion[data_categorias_evaluacion['OverallQual']==8].reset_index(drop=True)

# %%
data_cat_eva_8.corr()['SalePrice']
# Out:
# SalePrice      1.000000
# OverallQual         NaN
# OverallCond    0.066430
# ExterQual      0.254143
# ExterCond     -0.072089
# BsmtQual       0.303422
# BsmtCond       0.034838
# HeatingQC      0.186585
# KitchenQual    0.249702
# FireplaceQu    0.110521
# GarageQual     0.017864
# GarageCond     0.032571
# Name: SalePrice, dtype: float64

# %%
data_cat_eva_9 = data_categorias_evaluacion[data_categorias_evaluacion['OverallQual']==9].reset_index(drop=True)

# %%
data_cat_eva_9.corr()['SalePrice']
# Out:
# SalePrice      1.000000
# OverallQual         NaN
# OverallCond   -0.051709
# ExterQual      0.240823
# ExterCond           NaN
# BsmtQual       0.226026
# BsmtCond      -0.130572
# HeatingQC     -0.033591
# KitchenQual    0.183876
# FireplaceQu    0.014028
# GarageQual          NaN
# GarageCond          NaN
# Name: SalePrice, dtype: float64

# %%
data_cat_eva_10 = data_categorias_evaluacion[data_categorias_evaluacion['OverallQual']==10].reset_index(drop=True)

# %%
data_cat_eva_10.corr()['OverallCond']
# Out:
# SalePrice      0.002191
# OverallQual         NaN
# OverallCond    1.000000
# ExterQual     -0.296174
# ExterCond      0.828552
# BsmtQual      -0.983415
# BsmtCond      -0.096374
# HeatingQC     -0.674617
# KitchenQual   -0.296174
# FireplaceQu   -0.248787
# GarageQual     0.927173
# GarageCond          NaN
# Name: OverallCond, dtype: float64

# %% [markdown]
# # Conclusiones

# %% [markdown]
# * No necesariamente el inmueble con mejor condicion es el más costoso, este dependerá de los     materiales con los que esté construido
#
#
# * El número y condiciones de habitaciones, baños, sótanos, calidad de la cocina, los pies cuadrados del primer piso, la calidad de los exteriores y el tamaño del garage para guardar autos,  son los que ejercen mayor influencia en el costo del inmueble
#
#
# * Tendiendo modelos predrictivos para determinar el costo de un inmueble, puede funcionar como un referente
